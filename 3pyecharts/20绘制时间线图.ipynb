# %%
from pyecharts.charts import Timeline,Bar
from pyecharts.globals import ThemeType
from pyecharts.faker import Faker
from pyecharts.globals import ChartType
import pyecharts.options as opts

timeline = Timeline(init_opts=opts.InitOpts(theme=ThemeType.DARK))
for i in range(2020,2030):
    bar = Bar(init_opts=opts.InitOpts(theme=ThemeType.DARK))
    bar.add_xaxis(Faker.choose())
    bar.add_yaxis('A',Faker.values())
    bar.add_yaxis('B',Faker.values())
    timeline.add(bar,f'{i}年')

timeline.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="7f8b9f8a40ce401a88afc66851647376" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_7f8b9f8a40ce401a88afc66851647376 = echarts.init(
#                     document.getElementById('7f8b9f8a40ce401a88afc66851647376'), 'dark', {renderer: 'canvas'});
#                 var option_7f8b9f8a40ce401a88afc66851647376 = {
#     "baseOption": {
#         "series": [
#             {
#                 "type": "bar",
#                 "name": "A",
#                 "legendHoverLink": true,
#                 "data": [
#                     65,
#                     122,
#                     50,
#                     34,
#                     132,
#                     61,
#                     67
#                 ],
#                 "realtimeSort": false,
#                 "showBackground": false,
#                 "stackStrategy": "samesign",
#                 "cursor": "pointer",
#                 "barMinHeight": 0,
#                 "barCategoryGap": "20%",
#                 "barGap": "30%",
#                 "large": false,
#                 "largeThreshold": 400,
#                 "seriesLayoutBy": "column",
#                 "datasetIndex": 0,
#                 "clip": true,
#                 "zlevel": 0,
#                 "z": 2,
#                 "label": {
#                     "show": true,
#                     "margin": 8
#                 }
#             },
#             {
#                 "type": "bar",
#                 "name": "B",
#                 "legendHoverLink": true,
#                 "data": [
#                     23,
#                     51,
#                     86,
#                     150,
#                     133,
#                     149,
#                     89
#                 ],
#                 "realtimeSort": false,
#                 "showBackground": false,
#                 "stackStrategy": "samesign",
#                 "cursor": "pointer",
#                 "barMinHeight": 0,
#                 "barCategoryGap": "20%",
#                 "barGap": "30%",
#                 "large": false,
#                 "largeThreshold": 400,
#                 "seriesLayoutBy": "column",
#                 "datasetIndex": 0,
#                 "clip": true,
#                 "zlevel": 0,
#                 "z": 2,
#                 "label": {
#                     "show": true,
#                     "margin": 8
#                 }
#             }
#         ],
#         "timeline": {
#             "axisType": "category",
#             "currentIndex": 0,
#             "orient": "horizontal",
#             "autoPlay": false,
#             "controlPosition": "left",
#             "loop": true,
#             "rewind": false,
#             "show": true,
#             "inverse": false,
#             "bottom": "-5px",
#             "progress": {},
#             "data": [
#                 "2020\u5e74",
#                 "2021\u5e74",
#                 "2022\u5e74",
#                 "2023\u5e74",
#                 "2024\u5e74",
#                 "2025\u5e74",
#                 "2026\u5e74",
#                 "2027\u5e74",
#                 "2028\u5e74",
#                 "2029\u5e74"
#             ]
#         },
#         "xAxis": [
#             {
#                 "show": true,
#                 "scale": false,
#                 "nameLocation": "end",
#                 "nameGap": 15,
#                 "gridIndex": 0,
#                 "inverse": false,
#                 "offset": 0,
#                 "splitNumber": 5,
#                 "minInterval": 0,
#                 "splitLine": {
#                     "show": true,
#                     "lineStyle": {
#                         "show": true,
#                         "width": 1,
#                         "opacity": 1,
#                         "curveness": 0,
#                         "type": "solid"
#                     }
#                 },
#                 "data": [
#                     "\u54c8\u58eb\u5947",
#                     "\u8428\u6469\u8036",
#                     "\u6cf0\u8fea",
#                     "\u91d1\u6bdb",
#                     "\u7267\u7f8a\u72ac",
#                     "\u5409\u5a03\u5a03",
#                     "\u67ef\u57fa"
#                 ]
#             }
#         ],
#         "yAxis": [
#             {
#                 "show": true,
#                 "scale": false,
#                 "nameLocation": "end",
#                 "nameGap": 15,
#                 "gridIndex": 0,
#                 "inverse": false,
#                 "offset": 0,
#                 "splitNumber": 5,
#                 "minInterval": 0,
#                 "splitLine": {
#                     "show": true,
#                     "lineStyle": {
#                         "show": true,
#                         "width": 1,
#                         "opacity": 1,
#                         "curveness": 0,
#                         "type": "solid"
#                     }
#                 }
#             }
#         ],
#         "legend": [
#             {
#                 "data": [
#                     "A",
#                     "B"
#                 ],
#                 "selected": {}
#             }
#         ]
#     },
#     "options": [
#         {
#             "series": [
#                 {
#                     "type": "bar",
#                     "name": "A",
#                     "legendHoverLink": true,
#                     "data": [
#                         54,
#                         136,
#                         78,
#                         62,
#                         37,
#                         106,
#                         59
#                     ],
#                     "realtimeSort": false,
#                     "showBackground": false,
#                     "stackStrategy": "samesign",
#                     "cursor": "pointer",
#                     "barMinHeight": 0,
#                     "barCategoryGap": "20%",
#                     "barGap": "30%",
#                     "large": false,
#                     "largeThreshold": 400,
#                     "seriesLayoutBy": "column",
#                     "datasetIndex": 0,
#                     "clip": true,
#                     "zlevel": 0,
#                     "z": 2,
#                     "label": {
#                         "show": true,
#                         "margin": 8
#                     }
#                 },
#                 {
#                     "type": "bar",
#                     "name": "B",
#                     "legendHoverLink": true,
#                     "data": [
#                         21,
#                         58,
#                         89,
#                         58,
#                         147,
#                         146,
#                         31
#                     ],
#                     "realtimeSort": false,
#                     "showBackground": false,
#                     "stackStrategy": "samesign",
#                     "cursor": "pointer",
#                     "barMinHeight": 0,
#                     "barCategoryGap": "20%",
#                     "barGap": "30%",
#                     "large": false,
#                     "largeThreshold": 400,
#                     "seriesLayoutBy": "column",
#                     "datasetIndex": 0,
#                     "clip": true,
#                     "zlevel": 0,
#                     "z": 2,
#                     "label": {
#                         "show": true,
#                         "margin": 8
#                     }
#                 }
#             ],
#             "xAxis": [
#                 {
#                     "show": true,
#                     "scale": false,
#                     "nameLocation": "end",
#                     "nameGap": 15,
#                     "gridIndex": 0,
#                     "inverse": false,
#                     "offset": 0,
#                     "splitNumber": 5,
#                     "minInterval": 0,
#                     "splitLine": {
#                         "show": true,
#                         "lineStyle": {
#                             "show": true,
#                             "width": 1,
#                             "opacity": 1,
#                             "curveness"
