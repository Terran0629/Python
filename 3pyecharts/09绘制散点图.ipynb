# %%
from pyecharts.charts import Scatter
from pyecharts.globals import ThemeType
from pyecharts.faker import Faker
import pyecharts.options as opts
from random import randint

sca = Scatter(init_opts=opts.InitOpts(theme=ThemeType.DARK))
sca.add_xaxis([randint(0,100) for _ in range(100)])
sca.add_yaxis('',[randint(0,100) for _ in range(100)])
sca.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="ce0b6b3b7dce44dcae0aad936b3ad6d0" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_ce0b6b3b7dce44dcae0aad936b3ad6d0 = echarts.init(
#                     document.getElementById('ce0b6b3b7dce44dcae0aad936b3ad6d0'), 'dark', {renderer: 'canvas'});
#                 var option_ce0b6b3b7dce44dcae0aad936b3ad6d0 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "series": [
#         {
#             "type": "scatter",
#             "symbolSize": 10,
# ...

# %%
sca = Scatter(init_opts=opts.InitOpts(theme=ThemeType.DARK))
sca.add_xaxis([randint(0,100) for _ in range(100)])
sca.add_yaxis('',[randint(0,100) for _ in range(100)],
              label_opts=opts.LabelOpts(is_show=False),
              symbol_size=20)
sca.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="49e4873e248740a6a698c078f4da00b4" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_49e4873e248740a6a698c078f4da00b4 = echarts.init(
#                     document.getElementById('49e4873e248740a6a698c078f4da00b4'), 'dark', {renderer: 'canvas'});
#                 var option_49e4873e248740a6a698c078f4da00b4 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "series": [
#         {
#             "type": "scatter",
#             "symbolSize": 20,
# ...

# %%
sca = Scatter(init_opts=opts.InitOpts(theme=ThemeType.DARK))
sca.add_xaxis([randint(0,100) for _ in range(100)])
sca.add_yaxis('',[randint(0,100) for _ in range(100)],
              label_opts=opts.LabelOpts(is_show=False),
              symbol_size=20)

sca.set_global_opts(xaxis_opts=opts.AxisOpts(type_='value'),
                    visualmap_opts=opts.VisualMapOpts())

sca.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="b58f258dc2814fabab55924fdb36c053" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_b58f258dc2814fabab55924fdb36c053 = echarts.init(
#                     document.getElementById('b58f258dc2814fabab55924fdb36c053'), 'dark', {renderer: 'canvas'});
#                 var option_b58f258dc2814fabab55924fdb36c053 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "series": [
#         {
#             "type": "scatter",
#             "symbolSize": 20,
# ...
