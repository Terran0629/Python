# %%
import jqdatasdk as jq
import pandas as pd
jq.auth('15661317439','Ax020629.')
# Out:
# auth success

# %%
from jqdatasdk import *

#                            总市值                      市盈率
q = query(valuation).filter(valuation.market_cap > 200,valuation.pe_ratio < 10)

#                      按总市值降序排列
df = get_fundamentals(q.order_by(valuation.market_cap.desc()).limit(100),
                      date='2023-02-01') 
df
# Out:
#          id         code  pe_ratio  turnover_ratio  pb_ratio  ps_ratio  \
# 0   2053832  601398.XSHG    4.2394          0.0641    0.5027    1.6306
# 1   2053878  601939.XSHG    4.4234          0.5192    0.5300    1.6921
# 2   2051846  600036.XSHG    7.4081          0.4444    1.0811    2.9654
# 3   2053583  601288.XSHG    4.0557          0.0871    0.4676    1.3817
# 4   2052786  601857.XSHG    6.9314          0.0733    0.7085    0.2984
# ..      ...          ...       ...             ...       ...       ...
# 95  2053716  600348.XSHG    6.1041          1.6186    1.5953    1.0409
# 96  2052863  601216.XSHG    9.3651          0.5446    1.5532    1.7403
# 97  2054970  002064.XSHE    8.9365          0.3492    1.6628    1.3837
# 98  2055385  688234.XSHG -463.5203          1.6095    7.0653   95.3752
# 99  2053799  688538.XSHG  -23.3634          0.3232    2.3733    8.9392
#
#     pcf_ratio  capitalization  market_cap  circulating_cap  \
# ...
