# %%
from pyecharts.charts import WordCloud
from pyecharts.globals import ThemeType
from pyecharts.faker import Faker
import pyecharts.options as opts
from random import randint


word = WordCloud(init_opts=opts.InitOpts(theme=ThemeType.DARK))
data = [ ['ThinkPad','15.7'], 
     ['联想','14.5'],
     ['惠普','14.4'], 
     ['华为','11.7'], 
     ['华硕','8.2'], 
     ['戴尔','8.1'], 
     ['Acer 宏碁','4.5'], 
     ['苹果','3.5'], 
     ['神舟','3.2'], 
     ['ROG','3.1'], 
     ['机械革命','2.4'], 
     ['msi 微星','1.8'], 
     ['外星人','1.5'], 
     ['微软','1.4'], 
     ['荣耀','1.2'], 
     ['雷神','1'], 
     ['三星','0.7'], 
     ['红米','0.6'], 
     ['机械师','0.5'], 
     ['小米','0.5'], 
     ['炫龙','0.4'], 
     ['雷蛇','0.2'], 
     ['壹号本','0.1'], 
     ['a 豆','0.1'],
     ['未来人类','0.1'], 
     ['技嘉','0.1'], 
     ['中柏','0.1'], 
     ['VAIO','0.1'], 
     ['火影','0.1'], 
     ['LG','0.1'], 
     ['松下','0'], 
     ['麦本本','0'], 
     ['吾空','0'], 
     ['长城','0'], 
     ['GPD','0'], 
     ['清华同方','0'], 
     ['神基','0'], 
     ['爱尔轩','0'], 
     ['酷比魔方','0'], 
     ['海尔','0'], 
     ['谷歌','0'], 
     ['台电','0'], 
     ['iru','0'], 
     ['攀升 IPASON','0'], 
     ['NEC','0'], 
     ['夏普','0'],
     ['京东京造','0'], 
     ['锡恩帝','0'], 
     ['皓勤','0'], 
     ['Intel','0'], ]
word.add('',data,shape='circle',word_gap=80,emphasis_shadow_color='red')
word.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min', 'echarts-wordcloud':'https://assets.pyecharts.org/assets/v5/echarts-wordcloud.min'
#         }
#     });
# </script>
#
#         <div id="f794a09f91764e8ebd3c6c4475bdc78c" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'echarts-wordcloud'], function(echarts) {
#                 var chart_f794a09f91764e8ebd3c6c4475bdc78c = echarts.init(
#                     document.getElementById('f794a09f91764e8ebd3c6c4475bdc78c'), 'dark', {renderer: 'canvas'});
#                 var option_f794a09f91764e8ebd3c6c4475bdc78c = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "series": [
#         {
#             "type": "wordCloud",
#             "shape": "circle",
#             "rotationRange": [
#                 -90,
#                 90
#             ],
#             "rotationStep": 45,
#             "girdSize": 80,
#             "sizeRange": [
#                 12,
#                 60
#             ],
#             "data": [
#                 {
#                     "name": "ThinkPad",
#                     "value": "15.7",
#                     "textStyle": {
#                         "color": "rgb(29,16,27)"
#                     }
#                 },
#                 {
#                     "name": "\u8054\u60f3",
#                     "value": "14.5",
#                     "textStyle": {
#                         "color": "rgb(30,104,142)"
#                     }
#                 },
#                 {
#                     "name": "\u60e0\u666e",
#                     "value": "14.4",
#                     "textStyle": {
#                         "color": "rgb(131,116,86)"
#                     }
#                 },
#                 {
#                     "name": "\u534e\u4e3a",
#                     "value": "11.7",
#                     "textStyle": {
#                         "color": "rgb(76,16,86)"
#                     }
#                 },
#                 {
#                     "name": "\u534e\u7855",
#                     "value": "8.2",
#                     "textStyle": {
#                         "color": "rgb(157,59,104)"
#                     }
#                 },
#                 {
#                     "name": "\u6234\u5c14",
#                     "value": "8.1",
#                     "textStyle": {
#                         "color": "rgb(41,17,102)"
#                     }
#                 },
#                 {
#                     "name": "Acer \u5b8f\u7881",
#                     "value": "4.5",
#                     "textStyle": {
#                         "color": "rgb(131,2,84)"
#                     }
#                 },
#                 {
#                     "name": "\u82f9\u679c",
#                     "value": "3.5",
#                     "textStyle": {
#                         "color": "rgb(76,5,63)"
#                     }
#                 },
#                 {
#                     "name": "\u795e\u821f",
#                     "value": "3.2",
#                     "textStyle": {
#                         "color": "rgb(66,119,47)"
#                     }
#                 },
#                 {
#                     "name": "ROG",
#                     "value": "3.1",
#                     "textStyle": {
#                         "color": "rgb(133,159,78)"
#                     }
#                 },
#                 {
#                     "name": "\u673a\u68b0\u9769\u547d",
#                     "value": "2.4",
#                     "textStyle": {
#                         "color": "rgb(25,43,149)"
#                     }
#                 },
#                 {
#                     "name": "msi \u5fae\u661f",
#                     "value": "1.8",
#                     "textStyle": {
#                         "color": "rgb(124,76,96)"
#                     }
#                 },
#                 {
#                     "name": "\u5916\u661f\u4eba",
#                     "value": "1.5",
#                     "textStyle": {
#                         "color": "rgb(119,130,109)"
#                     }
#                 },
#                 {
#                     "name": "\u5fae\u8f6f",
#                     "value": "1.4",
#                     "textStyle": {
#                         "color": "rgb(116,69,80)"
#                     }
#                 },
#                 {
#                     "name": "\u8363\u8000",
#                     "value": "1.2",
#                     "textStyle": {
#                         "color": "rgb(130,84,28)"
#                     }
#                 },
#                 {
#                     "name": "\u96f7\u795e",
#                     "value": "1",
#                     "textStyle": {
#                         "color": "rgb(14,26,83)"
#                     }
#                 },
#                 {
#                     "name": "\u4e09\u661f",
#                     "value": "0.7",
#                     "textStyle": {
#                         "color": "rgb(85,82,123)"
#                     }
#                 },
#                 {
#                     "name": "\u7ea2\u7c73",
#                     "value": "0.6",
#                     "textStyle": {
#                         "color": "rgb(26,130,13)"
#                     }
#                 },
#                 {
#                     "name": "\u673a\u68b0\u5e08",
#                     "value": "0.5",
#                     "textStyle": {
#                         "color": "rgb(144,67,149)"
#                     }
#                 },
#                 {
#                     "name": "\u5c0f\u7c73",
#                     "value": "0.5",
#                     "textStyle": {
#                         "color": "rgb(4,135,101)"
#                     }
#                 },
#                 {
#                     "name": "\u70ab\u9f99",
#                     "value": "0.4",
#                     "textStyle": {
#                         "color": "rgb(73,127,145)"
#                     }
#                 },
#                 {
#                     "name": "\u96f7\u86c7",
#                     "value": "0.2",
#                     "textStyle": {
#                         "color": "rgb(47,3,149)"
#                     }
#                 },
#                 {
#                     "name": "\u58f9\u53f7\u672c",
#                     "value": "0.1",
#                     "textStyle": {
#                         "color": "rgb(73,108,154)"
#                     }
#                 },
#                 {
#                     "name": "a \u8c46",
#                     "value": "0.1",
#                     "textStyle": {
#                         "color": "rgb(142,32,156)"
#                     }
#                 },
#                 {
#                     "name": "\u672a\u6765\u4eba\u7c7b",
#                     "value": "0.1",
#                     "textStyle": {
#                         "color": "rgb(145,155,4)"
#                     }
#                 },
#                 {
#                     "name": "\u6280\u5609",
#                     "value": "0.1",
#                     "textStyle": {
#                         "color": "rgb(114,35,69)"
#                     }
#                 },
#                 {
#                     "name": "\u4e2d\u67cf",
#                     "value": "0.1",
#                     "textStyle": {
#                         "color": "rgb(43,37,56)"
#                     }
#                 },
#                 {
#                     "name": "VAIO",
#                     "value": "0.1",
#                     "textStyle": {
#                         "color": "rgb(118,23,83)"
#                     }
#                 },
#                 {
#                     "name": "\u706b\u5f71",
#                     "value": "0.1",
#                     "textStyle": {
#                         "color": "rgb(74,48,32)"
#                     }
#                 },
#                 {
#                     "name": "LG",
#                     "value": "0.1",
#                     "textStyle": {
#                         "color": "rgb(12,6,65)"
