# %%
import jqdatasdk as jq
import pandas as pd
jq.auth('15661317439','Ax020629.')
# Out:
# auth success

# %%
from jqdatasdk import *


q = query(valuation).filter(valuation.code.in_(['000001.XSHE','600000.XSHG']))

get_fundamentals_continuously(q,'2023-06-30',5)
# Out:
#           day         code       id       code.1  pe_ratio  turnover_ratio  \
# 0  2023-06-26  000001.XSHE  1332147  000001.XSHE    4.5900          0.3487
# 1  2023-06-27  000001.XSHE  1327131  000001.XSHE    4.6310          0.2379
# 2  2023-06-28  000001.XSHE  1322110  000001.XSHE    4.6392          0.1883
# 3  2023-06-29  000001.XSHE  1317081  000001.XSHE    4.5900          0.2504
# 4  2023-06-30  000001.XSHE  1312058  000001.XSHE    4.6105          0.2675
# 5  2023-06-26  600000.XSHG  1333027  600000.XSHG    4.4139          0.1159
# 6  2023-06-27  600000.XSHG  1327923  600000.XSHG    4.4324          0.0627
# 7  2023-06-28  600000.XSHG  1323000  600000.XSHG    4.4447          0.0539
# 8  2023-06-29  600000.XSHG  1317965  600000.XSHG    4.4262          0.0737
# 9  2023-06-30  600000.XSHG  1312910  600000.XSHG    4.4632          0.0662
#
#    pb_ratio  ps_ratio  pcf_ratio  capitalization  market_cap  circulating_cap  \
# ...
