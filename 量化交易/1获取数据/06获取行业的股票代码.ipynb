# %%
import jqdatasdk as jq
import pandas as pd
jq.auth('15661317439','Ax020629.')
# Out:
# auth success

# %%
from jqdatasdk import *
# 行业编码,可查询
# https://www.joinquant.com/help/api/help#name:plateData

# 获取汽车制造业的股票代码
stocks = get_industry_stocks("C36",'2023-06-01') 
stocks
# Out:
# ['000030.XSHE',
#  '000338.XSHE',
#  '000549.XSHE',
#  '000550.XSHE',
#  '000559.XSHE',
#  '000572.XSHE',
#  '000581.XSHE',
#  '000625.XSHE',
#  '000700.XSHE',
#  '000760.XSHE',
#  '000800.XSHE',
#  '000868.XSHE',
#  '000901.XSHE',
#  '000951.XSHE',
#  '000957.XSHE',
#  '000980.XSHE',
#  '000981.XSHE',
#  '001260.XSHE',
#  '001278.XSHE',
#  '001282.XSHE',
#  '001311.XSHE',
#  '001319.XSHE',
#  '002048.XSHE',
#  '002085.XSHE',
#  '002101.XSHE',
#  '002126.XSHE',
#  '002190.XSHE',
#  '002213.XSHE',
#  '002239.XSHE',
#  '002265.XSHE',
#  '002283.XSHE',
#  '002284.XSHE',
#  '002328.XSHE',
#  '002355.XSHE',
#  '002363.XSHE',
#  '002406.XSHE',
#  '002434.XSHE',
#  '002448.XSHE',
#  '002454.XSHE',
#  '002488.XSHE',
#  '002510.XSHE',
#  '002536.XSHE',
#  '002590.XSHE',
#  '002592.XSHE',
#  '002593.XSHE',
#  '002594.XSHE',
#  '002662.XSHE',
#  '002664.XSHE',
#  '002703.XSHE',
#  '002708.XSHE',
#  '002715.XSHE',
#  '002725.XSHE',
#  '002765.XSHE',
#  '002863.XSHE',
#  '002865.XSHE',
# ...
