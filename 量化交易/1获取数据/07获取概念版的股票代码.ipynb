# %%
import jqdatasdk as jq
import pandas as pd
jq.auth('15661317439','Ax020629.')
# Out:
# auth success

# %%
from jqdatasdk import *
'''
概念版块 VS 行业板块
股市中，行业板块比概念板块的风险更小
行业板块的波动性小，更加稳定，而概念板块的波动性大
在炒股时，行业板块是决定因素，是选股的依据，而概念板块只是参考因素
'''
# Out:
# '\n概念版块 VS 行业板块\n股市中，行业板块比概念板块的风险更小\n行业板块的波动性小，更加稳定，而概念板块的波动性大\n在炒股时，行业板块是决定因素，是选股的依据，而概念板块只是参考因素\n'

# %%
stocks = get_concept_stocks('SC0047','2023-06-02')
stocks
# Out:
# ['000004.XSHE',
#  '000049.XSHE',
#  '000063.XSHE',
#  '000066.XSHE',
#  '000070.XSHE',
#  '000547.XSHE',
#  '000586.XSHE',
#  '000630.XSHE',
#  '000636.XSHE',
#  '000665.XSHE',
#  '000801.XSHE',
#  '000810.XSHE',
#  '000818.XSHE',
#  '000823.XSHE',
#  '000836.XSHE',
#  '000881.XSHE',
#  '000889.XSHE',
#  '000909.XSHE',
#  '000938.XSHE',
#  '000969.XSHE',
#  '000988.XSHE',
#  '001270.XSHE',
#  '002023.XSHE',
#  '002025.XSHE',
#  '002049.XSHE',
#  '002056.XSHE',
#  '002079.XSHE',
#  '002080.XSHE',
#  '002089.XSHE',
#  '002090.XSHE',
#  '002093.XSHE',
#  '002101.XSHE',
#  '002115.XSHE',
#  '002123.XSHE',
#  '002137.XSHE',
#  '002138.XSHE',
#  '002149.XSHE',
#  '002151.XSHE',
#  '002179.XSHE',
#  '002182.XSHE',
#  '002185.XSHE',
#  '002194.XSHE',
#  '002217.XSHE',
#  '002231.XSHE',
#  '002238.XSHE',
#  '002268.XSHE',
#  '002276.XSHE',
#  '002281.XSHE',
#  '002288.XSHE',
#  '002309.XSHE',
#  '002313.XSHE',
#  '002355.XSHE',
#  '002364.XSHE',
#  '002384.XSHE',
#  '002396.XSHE',
# ...
