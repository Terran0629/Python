# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

data = np.random.rand(3,3)
plt.subplot(121)
sns.heatmap(data=data)
plt.subplot(122)
sns.heatmap(data=data,vmin=0.2,vmax=0.7)
# Out:
# <Axes: >

# %%
data = sns.load_dataset('flights')
data = data.pivot('month','year','passengers')

                      #显示数字  #数字格式  #间隙       #右侧图例  #热力图颜色
sns.heatmap(data=data,annot=True,fmt='d',linewidths=0.5,cbar=False,cmap='YlGnBu')
# Out:
# C:\Users\伟力思\AppData\Local\Temp\ipykernel_16716\24422658.py:2: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   data = data.pivot('month','year','passengers')
# <Axes: xlabel='year', ylabel='month'>
