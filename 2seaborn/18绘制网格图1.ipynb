# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np


data = sns.load_dataset('tips')
sns.catplot(data=data,x='day',y='total_bill',kind='bar',col='sex',row='time',hue='smoker')
