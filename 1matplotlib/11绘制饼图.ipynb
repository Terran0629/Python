# %%
import matplotlib.pyplot as plt

# 示例数据
products = ['Product A', 'Product B', 'Product C', 'Product D', 'Product E']
sales = [23, 38, 56, 42, 15]
a = []
for i in sales:
    a.append((i/sum(sales)))

plt.pie(a,explode=(0,0.05,0.1,0,0.05),labels=products,autopct='%0.01f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x1cc43d39010>,
# ...
#  [Text(1.0065090565610888, 0.4437786825214872, 'Product A'),
#   Text(0.0622597244828599, 1.1483134270343263, 'Product B'),
#   Text(-1.1968718717645261, -0.0865893906831543, 'Product C'),
#   Text(0.29428127675047705, -1.0599049627934145, 'Product D'),
#   Text(1.1080825187121717, -0.30765749092861366, 'Product E')],
#  [Text(0.5490049399424121, 0.2420610995571748, '13.2%'),
#   Text(0.0351902790555295, 0.6490467196280972, '21.8%'),
#   Text(-0.6981752585293068, -0.05051047789850667, '32.2%'),
#   Text(0.16051706004571475, -0.5781299797054987, '24.1%'),
#   Text(0.6263075105764447, -0.1738933644379121, '8.6%')])
