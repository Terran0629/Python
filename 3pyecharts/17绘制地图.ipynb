# %%
from pyecharts.charts import Map
from pyecharts.globals import ThemeType
from pyecharts.faker import Faker
import pyecharts.options as opts
from random import randint


map = Map(init_opts=opts.InitOpts(theme=ThemeType.DARK))
map.add('',[['内蒙古自治区',100],['吉林省',50]],maptype='china')
map.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min', 'china':'https://assets.pyecharts.org/assets/v5/maps/china'
#         }
#     });
# </script>
#
#         <div id="944ae0241b61498b8f14e7b8090f431c" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'china'], function(echarts) {
#                 var chart_944ae0241b61498b8f14e7b8090f431c = echarts.init(
#                     document.getElementById('944ae0241b61498b8f14e7b8090f431c'), 'dark', {renderer: 'canvas'});
#                 var option_944ae0241b61498b8f14e7b8090f431c = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "series": [
# ...

# %%
map = Map(init_opts=opts.InitOpts(theme=ThemeType.DARK))
map.add('',[['内蒙古自治区',100],['吉林省',50]],maptype='china',is_map_symbol_show=False)
map.set_global_opts(visualmap_opts=opts.VisualMapOpts())
map.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min', 'china':'https://assets.pyecharts.org/assets/v5/maps/china'
#         }
#     });
# </script>
#
#         <div id="78cb18fe886e40818ad679d4088076df" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'china'], function(echarts) {
#                 var chart_78cb18fe886e40818ad679d4088076df = echarts.init(
#                     document.getElementById('78cb18fe886e40818ad679d4088076df'), 'dark', {renderer: 'canvas'});
#                 var option_78cb18fe886e40818ad679d4088076df = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "series": [
# ...
