# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np


data = sns.load_dataset('titanic')
sns.pointplot(data=data,x='sex',y='survived',hue='class')
# Out:
# <Axes: xlabel='sex', ylabel='survived'>

# %%
data = sns.load_dataset('titanic')
sns.pointplot(data=data,x='sex',y='survived',hue='class',palette={'First':'y','Second':'b','Third':'red'}
              ,markers=['^','o','x'],linestyles=['-','--',':'])
# Out:
# d:\Anaconda\Lib\site-packages\seaborn\categorical.py:1728: UserWarning: You passed a edgecolor/edgecolors ((1.0, 0.0, 0.0)) for an unfilled marker ('x').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   ax.scatter(x, y, label=hue_level,
# <Axes: xlabel='sex', ylabel='survived'>
