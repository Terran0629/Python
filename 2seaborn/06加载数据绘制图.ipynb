# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

data = sns.load_dataset('titanic')  # 默认文件格式为csv

plt.subplot(121)
sns.barplot(x='sex',y='survived',data=data)
plt.subplot(122)
sns.barplot(x='sex',y='survived',data=data,hue='class')
# Out:
# <Axes: xlabel='sex', ylabel='survived'>
