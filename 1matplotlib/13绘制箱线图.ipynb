# %%
import matplotlib.pyplot as plt
import numpy as np

data=[np.random.normal(0,std,100) for std in range(1,4)]

plt.boxplot(data,notch=True)
plt.xticks([i+1 for i in range(len(data))],['box1','box2','box3'])
# Out:
# ([<matplotlib.axis.XTick at 0x13ea8bcbb10>,
#   <matplotlib.axis.XTick at 0x13e89cefcd0>,
#   <matplotlib.axis.XTick at 0x13ea8bcb410>],
#  [Text(1, 0, 'box1'), Text(2, 0, 'box2'), Text(3, 0, 'box3')])
